# %%
import numpy as np  # numpy used for linear algebra functions
import pandas as pd # pandas used to explore and manipulate dataframes

# %%
location = "datasets/weekly_call_data/Kickstartercombo.csv"
df = pd.read_csv(location)

# %%
df.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000004038                                     Where is Hank?
# 2           2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4           4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency             launched             deadline  backers  usd pledged  \
# ...

# %%
#df= pd.DataFrame(data = "Columns"= ["main_category"])
#df
df_film= df.loc[df['main_category'] == "Film & Video"]
df_film.head(100)
# Out:
#      Unnamed: 0          ID  \
# 1             1  1000004038
# 3             3  1000011046
# 8             8   100004195
# 24           24  1000104688
# 31           31  1000129669
# 33           33  1000132945
# 38           38  1000182258
# 40           40  1000184224
# 43           43  1000201265
# 46           46  1000216800
# 49           49  1000227361
# 50           50  1000230071
# 52           52  1000233415
# 69           69  1000320473
# 73           73  1000332383
# 85           85  1000386601
# 86           86  1000389241
# 87           87  1000392220
# 90           90  1000405957
# 96           96   100044420
# 105         105  1000499845
# 115         115  1000542390
# 117         117  1000545028
# 126         126    10005784
# 139         139  1000639526
# 140         140  1000644119
# 147         147  1000674477
# 150         150  1000694855
# 155         155  1000719127
# 159         159  1000741180
# ..          ...         ...
# 357         357  1001904397
# ...

# %%
df_film.isnull().sum()
# Out:
# Unnamed: 0              0
# ID                      0
# name                    2
# main_category           0
# category                0
# country                 0
# state                   0
# goal                    0
# pledged                 0
# currency                0
# launched                0
# deadline                0
# backers                 0
# usd pledged          1776
# usd_goal_real       57746
# usd_pledged_real    57746
# dtype: int64

# %%
df_film[df_film["name"].isnull()]
# Out:
#         Unnamed: 0          ID name main_category        category country  \
# 142830      142830  1848699072  NaN  Film & Video  Narrative Film      US
# 490601      490601  1848699072  NaN  Film & Video  Narrative Film      US
#
#          state      goal  pledged currency             launched  \
# 142830  failed  200000.0    100.0      USD  2012-01-01 12:35:00
# 490601  failed  200000.0    100.0      USD  2012-01-01 12:35:31
#
#                    deadline  backers  usd pledged  usd_goal_real  \
# 142830  2012-02-29 15:04:00        1        100.0            NaN
# 490601           2012-02-29        1        100.0       200000.0
#
#         usd_pledged_real
# 142830               NaN
# 490601             100.0

# %%
df_live= df.loc[df['state'] == "live"]
df_live.head()
# Out:
#      Unnamed: 0          ID  \
# 92           92  1000415969
# 129         129  1000586849
# 174         174   100078996
# 179         179  1000834930
# 187         187   100089599
#
#                                                   name main_category  \
# 92                            Disaster Area: A Podcast    Publishing
# 129                       #NotMyPresident Protest Tees       Fashion
# 174  APP - CUSTOM SHOES/ Calzado Personalizado - MA...    Technology
# 179              Strawberry Fields Café and Patisserie          Food
# 187  CLOTHING LABEL WITH A 90's STATE OF MIND - MAD...       Fashion
#
#              category country state     goal  pledged currency  \
# 92   Radio & Podcasts      US  live   1000.0    125.0      USD
# 129           Apparel      US  live   2500.0     25.0      USD
# 174              Apps      MX  live  55000.0   1700.0      MXN
# 179              Food      CA  live  50000.0      0.0      CAD
# ...

# %%
df_suspended= df.loc[df['state'] == "suspended"]
df_suspended.head()
# Out:
#       Unnamed: 0          ID  \
# 329          329  1001732009
# 899          899   100524873
# 961          961  1005618996
# 1024        1024  1006032032
# 1348        1348    10080310
#
#                                                    name main_category  \
# 329   DotPen : Redefines drawing and writing for sma...        Design
# 899          PRESIDENT OF THE UNITED STATES (Suspended)    Publishing
# 961       Masters of the Tooniverse Podcast (Suspended)  Film & Video
# 1024          Buddy day in Heidepark Soltau (Suspended)   Photography
# 1348  parasuicidal tendancies a performance of rebir...           Art
#
#             category country      state     goal  pledged currency  \
# 329   Product Design      US  suspended  25000.0  39693.0      USD
# 899         Academic      US  suspended   5500.0      0.0      USD
# 961        Webseries      US  suspended   3200.0   3226.0      USD
# 1024          People      DE  suspended    200.0     13.0      EUR
# ...

# %%
df_undefined= df.loc[df['state'] == "undefined"]
df_undefined.head()
# Out:
#      Unnamed: 0          ID                                       name  \
# 150         150  1000694855              STREETFIGHTERZ WHEELIE MURICA
# 287         287   100149523                Duncan Woods - Chameleon EP
# 549         549  1003023003  The Making of Ashley Kelley's Debut Album
# 561         561  1003130892               Butter Side Down Debut Album
# 650         650  1003629045                    Chase Goehring debut EP
#
#     main_category      category country      state    goal  pledged currency  \
# 150  Film & Video  Film & Video    N,"0  undefined  6500.0   555.00      USD
# 287         Music         Music    N,"0  undefined  4500.0  4767.00      AUD
# 549         Music         Music    N,"0  undefined  3500.0  3576.00      USD
# 561         Music         Music    N,"0  undefined  6000.0  7007.80      USD
# 650         Music         Music    N,"0  undefined  3000.0  3660.38      USD
#
#                 launched             deadline  backers  usd pledged  \
# ...

# %%
df_film.head(100)
# Out:
#      Unnamed: 0          ID  \
# 1             1  1000004038
# 3             3  1000011046
# 8             8   100004195
# 24           24  1000104688
# 31           31  1000129669
# 33           33  1000132945
# 38           38  1000182258
# 40           40  1000184224
# 43           43  1000201265
# 46           46  1000216800
# 49           49  1000227361
# 50           50  1000230071
# 52           52  1000233415
# 69           69  1000320473
# 73           73  1000332383
# 85           85  1000386601
# 86           86  1000389241
# 87           87  1000392220
# 90           90  1000405957
# 96           96   100044420
# 105         105  1000499845
# 115         115  1000542390
# 117         117  1000545028
# 126         126    10005784
# 139         139  1000639526
# 140         140  1000644119
# 147         147  1000674477
# 150         150  1000694855
# 155         155  1000719127
# 159         159  1000741180
# ..          ...         ...
# 357         357  1001904397
# ...

# %%
df_film.drop(df_film[df_film['state']=='live'].index, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_film.head()
# Out:
#     Unnamed: 0          ID                                               name  \
# 1            1  1000004038                                     Where is Hank?
# 3            3  1000011046  Community Film Project: The Art of Neighborhoo...
# 8            8   100004195  STUDIO IN THE SKY - A Documentary Feature Film...
# 24          24  1000104688                                Permaculture Skills
# 31          31  1000129669                                   Squatch Watchers
#
#    main_category        category country       state     goal   pledged  \
# 1   Film & Video  Narrative Film      US      failed  45000.0    220.00
# 3   Film & Video    Film & Video      US    canceled  19500.0   1283.00
# 8   Film & Video     Documentary      US    canceled  65000.0   6240.57
# 24  Film & Video       Webseries      CA  successful  17757.0  48905.00
# 31  Film & Video       Webseries      US      failed  10000.0   1373.37
#
# ...

# %%
df_film.drop(df_film[df_film['state']=='undefined'].index, inplace=True)

# %%
df_film.head(100)
# Out:
#      Unnamed: 0          ID  \
# 1             1  1000004038
# 3             3  1000011046
# 8             8   100004195
# 24           24  1000104688
# 31           31  1000129669
# 33           33  1000132945
# 38           38  1000182258
# 40           40  1000184224
# 43           43  1000201265
# 46           46  1000216800
# 49           49  1000227361
# 50           50  1000230071
# 52           52  1000233415
# 69           69  1000320473
# 73           73  1000332383
# 85           85  1000386601
# 86           86  1000389241
# 87           87  1000392220
# 90           90  1000405957
# 96           96   100044420
# 105         105  1000499845
# 115         115  1000542390
# 117         117  1000545028
# 126         126    10005784
# 139         139  1000639526
# 140         140  1000644119
# 147         147  1000674477
# 155         155  1000719127
# 159         159  1000741180
# 161         161  1000752960
# ..          ...         ...
# 367         367  1001994928
# ...

# %%
df_film.drop(df_film[df_film['state']=='suspended'].index, inplace=True)

# %%
df_film.head(100)
# Out:
#      Unnamed: 0          ID  \
# 1             1  1000004038
# 3             3  1000011046
# 8             8   100004195
# 24           24  1000104688
# 31           31  1000129669
# 33           33  1000132945
# 38           38  1000182258
# 40           40  1000184224
# 43           43  1000201265
# 46           46  1000216800
# 49           49  1000227361
# 50           50  1000230071
# 52           52  1000233415
# 69           69  1000320473
# 73           73  1000332383
# 85           85  1000386601
# 86           86  1000389241
# 87           87  1000392220
# 90           90  1000405957
# 96           96   100044420
# 105         105  1000499845
# 115         115  1000542390
# 117         117  1000545028
# 126         126    10005784
# 139         139  1000639526
# 140         140  1000644119
# 147         147  1000674477
# 155         155  1000719127
# 159         159  1000741180
# 161         161  1000752960
# ..          ...         ...
# 367         367  1001994928
# ...

# %%
writer = pd.ExcelWriter('datasets/fvideo.xlsx', engine='xlsxwriter')
df_film.to_excel(writer, sheet_name='Sheet1')
writer.save()
